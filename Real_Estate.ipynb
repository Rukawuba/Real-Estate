# %% [markdown]
# <a href="https://colab.research.google.com/github/Rukawuba/Real-Estate/blob/main/Real_Estate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('/content/Metro_invt_fs_uc_sfrcondo_sm_month.csv', sep=',')
ds
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0      102001         0    United States    country       NaN   1421529.0
# 1      394913         1     New York, NY        msa        NY     73707.0
# 2      753899         2  Los Angeles, CA        msa        CA     21998.0
# 3      394463         3      Chicago, IL        msa        IL     38581.0
# 4      394514         4       Dallas, TX        msa        TX     24043.0
# ..        ...       ...              ...        ...       ...         ...
# 923    753929       935       Zapata, TX        msa        TX        55.0
# 924    394743       936    Ketchikan, AK        msa        AK        77.0
# 925    753874       937        Craig, CO        msa        CO       115.0
# 926    395188       938       Vernon, TX        msa        TX        21.0
# 927    394767       939       Lamesa, TX        msa        TX        35.0
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  ...  2023-04-30  \
# ...

# %%
import pandas as pd

# Show all columns (without truncation)
pd.set_option('display.max_columns', None)

# Show all rows (up to a reasonable limit)
pd.set_option('display.max_rows', 50)  # Adjust this limit as needed

# Optionally, increase column width for better readability
# pd.set_option('display.max_colwidth', None)  # Uncomment if needed

# Display your data (replace 'your_data' with your actual DataFrame)
ds
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0      102001         0    United States    country       NaN   1421529.0
# 1      394913         1     New York, NY        msa        NY     73707.0
# 2      753899         2  Los Angeles, CA        msa        CA     21998.0
# 3      394463         3      Chicago, IL        msa        IL     38581.0
# 4      394514         4       Dallas, TX        msa        TX     24043.0
# ..        ...       ...              ...        ...       ...         ...
# 923    753929       935       Zapata, TX        msa        TX        55.0
# 924    394743       936    Ketchikan, AK        msa        AK        77.0
# 925    753874       937        Craig, CO        msa        CO       115.0
# 926    395188       938       Vernon, TX        msa        TX        21.0
# 927    394767       939       Lamesa, TX        msa        TX        35.0
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  2018-08-31  2018-09-30  \
# ...

# %%
pd.set_option('display.max_rows', 100) # Adjust this limit as needed
ds
# Out:
#      RegionID  SizeRank       RegionName RegionType StateName  2018-03-31  \
# 0      102001         0    United States    country       NaN   1421529.0
# 1      394913         1     New York, NY        msa        NY     73707.0
# 2      753899         2  Los Angeles, CA        msa        CA     21998.0
# 3      394463         3      Chicago, IL        msa        IL     38581.0
# 4      394514         4       Dallas, TX        msa        TX     24043.0
# ..        ...       ...              ...        ...       ...         ...
# 923    753929       935       Zapata, TX        msa        TX        55.0
# 924    394743       936    Ketchikan, AK        msa        AK        77.0
# 925    753874       937        Craig, CO        msa        CO       115.0
# 926    395188       938       Vernon, TX        msa        TX        21.0
# 927    394767       939       Lamesa, TX        msa        TX        35.0
#
#      2018-04-30  2018-05-31  2018-06-30  2018-07-31  2018-08-31  2018-09-30  \
# ...

# %%
# !kaggle datasets download -d ahmedshahriarsakib/usa-real-estate-dataset
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 403, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
! pip install kaggle

# %%
# !mkdir /.kaggle
# !mv kaggle.json /.kaggle
# !mv /.kaggle /root/
# !chmod 600 ~/kaggle/kaggle.json
# Out:
# mv: cannot stat 'kaggle.json': No such file or directory
# mv: cannot move '/.kaggle' to '/root/.kaggle': Directory not empty
# chmod: cannot access '/root/kaggle/kaggle.json': No such file or directory

# %%
# !kaggle datasets download -d ahmedshahriarsakib/usa-real-estate-dataset
# Out:
# ...
#  50% 11.0M/22.2M [00:00<00:00, 112MB/s]
# 100% 22.2M/22.2M [00:00<00:00, 122MB/s]

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !unzip usa-real-estate-dataset.zip
# Out:
# Archive:  usa-real-estate-dataset.zip
#   inflating: realtor-data.zip.csv

# %%
import pandas as pd

df = pd.read_csv('realtor-data.zip.csv')

# %%
pd.set_option('display.max_columns', None)
df.head(5)
# Out:
#      status  bed  bath  acre_lot        city        state  zip_code  \
# 0  for_sale  3.0   2.0      0.12    Adjuntas  Puerto Rico     601.0
# 1  for_sale  4.0   2.0      0.08    Adjuntas  Puerto Rico     601.0
# 2  for_sale  2.0   1.0      0.15  Juana Diaz  Puerto Rico     795.0
# 3  for_sale  4.0   2.0      0.10       Ponce  Puerto Rico     731.0
# 4  for_sale  6.0   2.0      0.05    Mayaguez  Puerto Rico     680.0
#
#    house_size prev_sold_date     price
# 0       920.0            NaN  105000.0
# 1      1527.0            NaN   80000.0
# 2       748.0            NaN   67000.0
# 3      1800.0            NaN  145000.0
# 4         NaN            NaN   65000.0

# %%
df.describe()
# Out:
#                 bed          bath      acre_lot      zip_code    house_size  \
# count  1.663100e+06  1.658940e+06  1.582890e+06  2.001148e+06  1.356466e+06
# mean   3.386039e+00  2.428370e+00  2.758164e+01  1.096973e+04  2.143257e+03
# std    1.886923e+00  1.719025e+00  1.215055e+03  5.790174e+03  3.023623e+03
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  4.000000e+00
# 25%    2.000000e+00  2.000000e+00  1.200000e-01  7.043000e+03  1.216000e+03
# 50%    3.000000e+00  2.000000e+00  3.000000e-01  1.136100e+04  1.719000e+03
# 75%    4.000000e+00  3.000000e+00  1.140000e+00  1.513200e+04  2.477000e+03
# max    1.420000e+02  1.980000e+02  1.000000e+05  9.999900e+04  1.450112e+06
#
#               price
# count  2.001395e+06
# mean   6.539247e+05
# std    2.267084e+06
# min    0.000000e+00
# 25%    1.690000e+05
# 50%    3.490000e+05
# 75%    6.490000e+05
# max    8.750000e+08

# %%
from google.colab import files

df.to_csv('realtor.csv', index=False)  # Replace 'your_data' with your DataFrame name
files.save('realtor.csv')  # This saves the file within Colab
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-bd91dd421005> in <cell line: 4>()
#       2
#       3 df.to_csv('realtor.csv', index=False)  # Replace 'your_data' with your DataFrame name
# ----> 4 files.save('realtor.csv')  # This saves the file within Colab
#
# AttributeError: module 'google.colab.files' has no attribute 'save'
